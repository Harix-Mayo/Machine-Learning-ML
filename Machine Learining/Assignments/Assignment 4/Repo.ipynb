# %%
centroids = np.zeros((k,img.shape[1]) , dtype=np.uint8)

# %%
while True:
    K_max = input("Enter K Maximum Value: ")
    try:
        K_max = int(K_max)
        break  
    except ValueError:
        print("Invalid input. Please enter a valid integer.")
print (type(K_max) , K_max)
# Out:
# Enter K Maximum Value: 4
# <class 'int'> 4

# %%
import numpy as np

arr = np.array([2 , 3 , 10])

for k in arr:
    print (k)
# Out:
# 2
# 3
# 10

# %%
from PIL import Image                          # for images
import copy                                    # help in deep copy
import random                                  # help in to generate randon numbers
import numpy as np                             # help in matrices related operations                      
import matplotlib.pyplot as plt                # help in ploting and visuaization
# %matplotlib inline

Pics = ['Person' , 'Greenary' , 'My']
print ('There are 3 image in Current Directory named: ' , Pics)
Img_Name = input('Select Pic: ')
while (Img_Name not in Pics):
    Img_Name = input('Enter valid Name: ')
Img = Image.open(Img_Name)
Img = np.array(Img , dtype=np.uint8)
plt.imshow(Img)
# Out:
# There are 3 image in Current Directory named:  ['Person', 'Greenary', 'My']
# Select Pic: mu
# Enter valid Name: My
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 13
#      11 while (Img_Name not in Pics):
#      12     Img_Name = input('Enter valid Name: ')
# ---> 13 Img = Image.open(Img_Name)
#      14 Img = np.array(Img , dtype=np.uint8)
#      15 plt.imshow(Img)
#
# File D:\Anaconda\Lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'My'

# %%
from PIL import Image
import numpy as np

def image_to_numpy(image_path):
    # Open the image file
    image = Image.open(image_path)

    # Convert the image to a NumPy array
    image_array = np.array(image)

    return image_array

# Provide the path to your image file
image_path = "2.jpg"

# Call the function to convert the image to a NumPy array
image_np_array = image_to_numpy(image_path)

# Display the shape of the resulting NumPy array
#print("Shape of the NumPy array:", image_np_array.shape , image_np_array)
print (image_np_array[0:5 , 0:2])
# Out:
# [[[  0  26   4]
#   [ 42  70  48]]
#
#  [[ 44  72  50]
#   [103 131 109]]
#
#  [[ 40  68  46]
#   [110 138 116]]
#
#  [[ 38  66  44]
#   [110 138 116]]
#
#  [[ 41  69  47]
#   [114 142 120]]]

# %%
from PIL import Image
import numpy as np

Img = Image.open('My.jpg')

Img = np.array(Img , dtype=np.uint8)
#print (Img.shape)

#plt.imshow(Img)
Original_Rows = Img.shape[0]
Original_Cols = Img.shape[1]

#Img = Img.reshape((-1,3))
#print (Img.shape)

#Img = Img.reshape(Original_Rows , Original_Cols , 3)
plt.imshow(Img)
plt.show()
plt.imshow(Img)
plt.show()
#print (type(img) , img.shape , img)

plt.plot([1 , 2, 3 , 4 , 5 ,6 ] , [ 1 , 2 , 3 , 5 , 6 , 7 ] , color = 'blue')
plt.title('Testing set')
plt.xlabel('Inputs')
plt.ylabel('Outputs')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 27
#      25 plt.xlabel('Inputs')
#      26 plt.ylabel('Outputs')
# ---> 27 plt.set_axis_off()
#      28 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_axis_off'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create multiple 2D images (random in this case)
image1 = np.random.rand(10, 10)
image2 = np.random.rand(10, 10)

# Create a figure with multiple subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Display the first image without axis scales
axes[0].imshow(image1)
axes[0].set_axis_off()  # Hide axis scales for the first subplot

# Display the second image without axis scales
axes[1].imshow(image2, cmap='viridis')
axes[1].set_axis_off()  # Hide axis scales for the second subplot

plt.show()

# %%
index = 0
while (index < k):
    index2 = 0
    while (index2 < centroids.shape[1]):
        centroids[index][index2] = random.randint(1,10)
        index2 += 1
    index += 1   
print (centroids)

# %%
import numpy as np

# Create two NumPy arrays
array1 = np.array([10, 15, 20, 25])
array2 = np.array([3, 4, 5, 6])

# Perform element-wise floor division
result = np.floor_divide(array1, array2)

print("Array 1:", array1)
print("Array 2:", array2)
print("Result of floor division:", result)

print (not(False))
# Out:
# Array 1: [10 15 20 25]
# Array 2: [3 4 5 6]
# Result of floor division: [3 3 4 4]
# True
